# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Reshmi S/Downloads/emp.csv")
print(df.head())
print(df.tail())
print(df.info())
print(df.shape)
# Out:
#    Employee_ID     Name   Age  Gender Department   Salary  Experience
# 0          101    Rahul  25.0    Male         IT  50000.0         2.0
# 1          102    Priya  28.0  Female         HR  45000.0         3.0
# 2          103     Arun   NaN    Male         IT  55000.0         4.0
# 3          104    Sneha  26.0  Female        NaN  48000.0         2.0
# 4          105  Karthik  30.0    Male    Finance      NaN         5.0
#    Employee_ID   Name   Age  Gender Department   Salary  Experience
# 5          106  Divya  27.0  Female         IT  52000.0         NaN
# 6          107  Rahul  25.0    Male         IT  50000.0         2.0
# 7          108  Meena   NaN  Female         HR  47000.0         3.0
# 8          109   Ajay  35.0    Male    Finance  65000.0         8.0
# 9          110  Kavya  29.0  Female         IT      NaN         4.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  10 non-null     int64
#  1   Name         10 non-null     object
#  2   Age          8 non-null      float64
#  3   Gender       10 non-null     object
#  4   Department   9 non-null      object
#  5   Salary       8 non-null      float64
#  6   Experience   9 non-null      float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 692.0+ bytes
# None
# (10, 7)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Gender         0
# Department     1
# Salary         2
# Experience     1
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean,inplace=True)

# %%
df['Salary'].fillna(df['Salary'].mean,inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Gender         0
# Department     1
# Salary         0
# Experience     1
# dtype: int64

# %%
df['Department'].fillna(df['Department'].mode()[0],inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Gender         0
# Department     0
# Salary         0
# Experience     1
# dtype: int64

# %%
df['Experience'].fillna(df['Experience'].mean,inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Employee_ID    0
# Name           0
# Age            0
# Gender         0
# Department     0
# Salary         0
# Experience     0
# dtype: int64
